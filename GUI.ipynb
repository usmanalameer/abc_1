# %% [markdown]
# # Labels And Pack

# %%
# from tkinter import *

# root = Tk()

# #widthxheight
# root.geometry("450x350")

# #width,height
# root.minsize(200,300)
# #width,height
# root.maxsize(700,500)

# a_label = Label(text = 'My name is hamza')

# a_label.pack()


# root.mainloop()


from tkinter import *
root = Tk()

#widthxheight
root.geometry('400x600')

root.minsize(200,500)
root.maxsize(800,1000)

label1=Label(text='Hamza',fg='red',bg='black')

label1.pack()




root.mainloop()

# %%
# Important Label Options
# text - add texts
# bg/background - colour
# fg/foreground - colour
# font-sets the font
# padx - x padding
# pady - y padding
# relief - SUNKEN,GROOVE,RIDGE,RAISED

#Important Pack Options
# anchor - nw,ne,se,sw
# side - top,bottom,left,right
# fill - X,Y
# padx
# pady


from tkinter import *
root = Tk()
root.geometry("433x233")

label1 = Label(text = '''All widgets have their class in Tkinter module 
\n whose constructor accepts the parent window and
\n configuration options as parameters.
\n The Python script remains in mainloop() method
\n that handles all user events along with Tkinter's 
\n queued operations.
\n The steps to add a widget to a Python application are
\n importing the Tkinter module, coding for main 
\n window, adding the widget to it, and call the main
\n event loop for handling events.''',
               bg ="red",
               fg="white",
               padx = 30,
               pady=30,
               font='roboto 14 bold italic',
               borderwidth = 10,relief=GROOVE)


label2 = Label(text = '''All widgets have their class in Tkinter module 
\n whose constructor accepts the parent window and
\n configuration options as parameters.
\n The Python script remains in mainloop() method
\n that handles all user events along with Tkinter's 
\n queued operations.
\n The steps to add a widget to a Python application are
\n importing the Tkinter module, coding for main 
\n window, adding the widget to it, and call the main
\n event loop for handling events.''',
               bg ="red",
               fg="white",
               padx = 30,
               pady=30,
               font='roboto 14 bold italic',
               borderwidth = 10,relief=GROOVE)

label1.pack(anchor='sw',side = 'left',fill = Y,padx = 50,pady=50)
label2.pack(anchor='sw',side = 'left',fill = Y,padx = 50,pady=50)
root.mainloop()

# %%
from tkinter import *
from PIL import Image, ImageTk
root = Tk()
root.title("Introduction")

#widthxheight
root.geometry("1000x500")

#width,height
root.minsize(300,200)
#width,height
root.maxsize(700,400)






# photo = PhotoImage(file='download.png')
# a_label = Label(image = photo)
# a_label.pack()

photo = PhotoImage(file='download.png')
label1 = Label(image = photo)
label1.pack()

# image = Image.open('download.png')
# photo = ImageTk.PhotoImage(image)
# a_label = Label(image = photo)
# a_label.pack()

a_label = Label(text = 'My name is Hamza').pack()

root.mainloop()

# %% [markdown]
# # Frames

# %%
# from tkinter import *
# root = Tk()
# root.geometry("433x233")

# frame1 = Frame(root,bg = "grey",borderwidth=6)
# frame1.pack(side =LEFT)

# label1 = Label(frame1,text = "Hello World!")
# label1.pack()

# frame2 = Frame(root,bg = "grey",borderwidth=6)
# frame2.pack(side =LEFT)

# label2 = Label(frame2,text = "Hello World!")
# label2.pack()



# root.mainloop()

from tkinter import *
root = Tk()
root.geometry("500x400")

frame1 = Frame(root,bg = 'black',borderwidth = 4)
frame1.pack()

label1 = Label(frame1,text = "Hello World").pack()

root.mainloop()


# from tkinter import *
# root = Tk()
# root.geometry("500x800")

# frame1 = Frame(root,bg ='red',borderwidth=6)
# frame1.pack(side=LEFT)

# label1=Label(frame1,text='Hamza')
# label1.pack()

# root.mainloop()

# %% [markdown]
# # Buttons

# %%
from tkinter import *
# root = Tk()
# root.geometry("433x233")

# def hello():
#     print("Printing Hello World!")
    
# def bye():
#     print("Printing Goodbye!")

# frame1 = Frame(root,bg = "grey",borderwidth=6)
# frame1.pack(side =LEFT)

# button1 = Button(frame1,text = "Hello World!",command=hello)
# button1.pack()

# frame2 = Frame(root,bg = "grey",borderwidth=6)
# frame2.pack(side =LEFT)

# button2 = Button(frame2,text = "Hello World!",command=bye)
# button2.pack()

# root.mainloop()


# from tkinter import *
# root = Tk()
# root.geometry('400x500')
# root.title('Working On Buttons')

# def abc():
#     print("Hello")
    
# frame1 = Frame(root,bg='black')
# frame1.pack()

# button1 = Button(frame1,text="Hamza",command=hamza)
# button1.pack()


# root.mainloop()


root = Tk()
root.geometry('500x300')

def hamza():
    print("My name is hamza")

frame1 = Frame(root,bg = 'red').pack()

button1 = Button(frame1,text = "Hello World",bg='blue',fg = 'orange',command = hamza).pack()

root.mainloop()

# %% [markdown]
# # Widget and Grid

# %%
# Variable Classes in Tkinter
# BooleanVar , StringVar, IntVar

from tkinter import *
root = Tk()
root.geometry("433x233")

def getvals():
    print("The value of username",uservalue.get())
    print("The value of password",passvalue.get())


user = Label(root,text = "Username: ")
password = Label(root,text = "Password: ")
user.grid(row=1,column=4,padx = 5,pady = 6,sticky= S)
password.grid(row=2,column=4,padx = 5,pady= 6,sticky=S)

uservalue = StringVar()
passvalue = StringVar()

userentry = Entry(root,textvariable=uservalue)
userentry.grid(row=1,column=5,columnspan = 10)
passentry = Entry(root,show='*',textvariable=passvalue)
passentry.grid(row=2,column=5,columnspan=10)
# frame1 = Frame(root,bg='black')
# frame1.grid(row=5)
button1 = Button(root,text='Submit',command=getvals)
button1.grid(row=5,column = 5)
root.mainloop()

# %%
import tkinter as tk

def login():
    username = username_entry.get()
    password = password_entry.get()
    
    # Add your login logic here to check the username and password
    # For this example, let's just print them for demonstration purposes
    print("Username:", username)
    print("Password:", password)

    # Add your actual login verification logic here and open a new window if successful
    # For this example, let's just show a message box
    if username == "user" and password == "pass":
        tk.messagebox.showinfo("Login Successful", "Welcome, {}".format(username))
    else:
        tk.messagebox.showerror("Login Failed", "Invalid username or password")

# Create the main window
root = tk.Tk()
root.title("Login Window")
root.geometry('300x200')

# Create labels, entry widgets, and login button
tk.Label(root, text="Username:").grid(row=0, column=0, padx=10, pady=5)
username_entry = tk.Entry(root)
username_entry.grid(row=0, column=1, padx=10, pady=5)

tk.Label(root, text="Password:").grid(row=1, column=0, padx=10, pady=5)
password_entry = tk.Entry(root, show="")  # Use show="" to hide the password characters
password_entry.grid(row=1, column=1, padx=10, pady=5)

login_button = tk.Button(root, text="Login", command=login)
login_button.grid(row=2, column=0, columnspan=2, padx=10, pady=5)

# Calculate the number of columns in the grid
num_cols = root.grid_size()[0]

# Add an empty row in the middle to center the login widgets
tk.Label(root).grid(row=3, column=0, columnspan=num_cols)

# Placing username and entry in the middle
tk.Label(root, text="Username:").grid(row=4, column=0, padx=10, pady=5)
username_entry = tk.Entry(root)
username_entry.grid(row=4, column=1, padx=10, pady=5)

root.mainloop()

# %% [markdown]
# # Travel Form Using CheckButtons

# %%
from tkinter import *

root = Tk()

def getvals():
    print("It works!")
root.geometry("644x344")
#Heading
Label(root, text="Welcome to XYZ Travels", font="comicsansms 13 bold", pady=15).grid(row=0, column=3)

#Text for our form
name = Label(root, text="Name")
phone = Label(root, text="Phone")
gender = Label(root, text="Gender")
emergency = Label(root, text="Emergency Contact")
paymentmode = Label(root, text="Payment Mode")

#Pack text for our form
name.grid(row=1, column=2)
phone.grid(row=2, column=2)
gender.grid(row=3, column=2)
emergency.grid(row=4, column=2)
paymentmode.grid(row=5, column=2)

# Tkinter variable for storing entries
namevalue = StringVar()
phonevalue = StringVar()
gendervalue = StringVar()
emergencyvalue = StringVar()
paymentmodevalue = StringVar()
foodservicevalue = IntVar()


#Entries for our form
nameentry = Entry(root, textvariable=namevalue)
phoneentry = Entry(root, textvariable=phonevalue)
genderentry = Entry(root, textvariable=gendervalue)
emergencyentry = Entry(root, textvariable=emergencyvalue)
paymentmodeentry = Entry(root, textvariable=paymentmodevalue)

# Packing the Entries
nameentry.grid(row=1, column=3)
phoneentry.grid(row=2, column=3)
genderentry.grid(row=3, column=3)
emergencyentry.grid(row=4, column=3)
paymentmodeentry.grid(row=5, column=3)

#Checkbox & Packing it
foodservice = Checkbutton(text="Want to prebook your meals?", variable = foodservicevalue)
foodservice.grid(row=6, column=3)

#Button & packing it and assigning it a command
Button(text="Submit to XYZ Travels", command=getvals).grid(row=7, column=3)



root.mainloop()

# %% [markdown]
# # Canvas Widget

# %%
from tkinter import *

root = Tk()

canvas_width = 800
canvas_height = 400

root.geometry(f"{canvas_width}x{canvas_height}")
root.title("CANVAS")
can_widget = Canvas(root, width=canvas_width, height=canvas_height)
can_widget.pack()

# The line goes from the point x1, y1 to x2, y2
can_widget.create_line(0, 0, 800, 400, fill="red")
can_widget.create_line(0, 400, 800, 0, fill="red")

# To create a rectangle specify parameters in this order - coors of top left and coors of bottom right
can_widget.create_rectangle(3, 5, 700, 300, fill="blue")

can_widget.create_text(200, 200, text="python")

can_widget.create_oval(344,233,244,355)


root.mainloop()

# %% [markdown]
# # Menus and submenus

# %%
from tkinter import *
root = Tk()
root.geometry("733x566")
root.title("Menus and Submenus")

def myfunc():
    print("Hello World")

# #Use these to create a non dropdown menu
# mymenu = Menu(root)
# mymenu.add_command(label="File", command=myfunc)
# mymenu.add_command(label="Exit", command=quit)
# root.config(menu=mymenu)


mainmenu = Menu(root)

m1 = Menu(mainmenu, tearoff=0)
m1.add_command(label="New project", command=myfunc)
m1.add_command(label="Save", command=myfunc)
m1.add_separator()
m1.add_command(label="Save As", command=myfunc)
m1.add_command(label="Print", command=myfunc)
root.config(menu=mainmenu)
mainmenu.add_cascade(label="File", menu=m1)

m2 = Menu(mainmenu, tearoff=0)
m2.add_command(label="Cut", command=myfunc)
m2.add_command(label="Copy", command=myfunc)
m2.add_separator()
m2.add_command(label="Paste", command=myfunc)
m2.add_command(label="Find", command=myfunc)
root.config(menu=mainmenu)
mainmenu.add_cascade(label="Edit", menu=m2)

root.mainloop()
# Out:
# Hello World
# Hello World

# %% [markdown]
# # Message Box

# %%
from tkinter import *
import tkinter.messagebox as tmsg
root = Tk()
root.geometry("733x566")
root.title("Message Box")

def myfunc():
    print("Hello World")

def help():
    print("I will help you")
    tmsg.showinfo("Help", "I will help you with this gui")

def rate():
    print("Rate us")
    value = tmsg.askquestion("Was your experience Good?", "You used this gui.. Was your experience Good?")
    if value == "yes":
        msg = "Great. Rate us on appstore please"
    else:
        msg = "Tell us what went wrong. We will call you soon"
    tmsg.showinfo("Experience", msg)

mainmenu = Menu(root)

m1 = Menu(mainmenu, tearoff=0)
m1.add_command(label="New project", command=myfunc)
m1.add_command(label="Save", command=myfunc)
m1.add_separator()
m1.add_command(label="Save As", command=myfunc)
m1.add_command(label="Print", command=myfunc)
root.config(menu=mainmenu)
mainmenu.add_cascade(label="File", menu=m1)

m2 = Menu(mainmenu, tearoff=0)
m2.add_command(label="Cut", command=myfunc)
m2.add_command(label="Copy", command=myfunc)
m2.add_separator()
m2.add_command(label="Paste", command=myfunc)
m2.add_command(label="Find", command=myfunc)
root.config(menu=mainmenu)
mainmenu.add_cascade(label="Edit", menu=m2)


m3 = Menu(mainmenu, tearoff=0)
m3.add_command(label = "Help", command=help)
m3.add_command(label = "Rate us", command=rate)
mainmenu.add_cascade(label="Help", menu=m3)
root.config(menu=mainmenu)
root.mainloop()
# Out:
# I will help you
